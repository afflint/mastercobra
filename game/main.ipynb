# %% [markdown]
# # Blackboard for objects

# %%
import nbimporter
from teams import Team, Match
from players import Player
from utils import FIFA
from collections import defaultdict
import numpy as np

# %%
football = '../data/fifa/fifa_2018.csv'
data = FIFA.load(football)

# %%
H = Team('Juventus', data)
A = Team('Roma', data)

# %%
H.selection(module={Player.DEF: 4, Player.MID: 3, Player.ATT: 3})

# %%
A.selection(module={Player.DEF: 4, Player.MID: 3, Player.ATT: 3})

# %%
match = Match(H, A, duration=90)

# %%
match.kickoff(verbose=True, sleep=0)
# Out:
# min 1: K. Manolas is in possession
# min 1: K. Manolas fails passing to H. Moreno
# min 2: G. Higuaín is in possession
# min 2: A. Kolarov intercept passage of G. Higuaín
# min 3: A. Kolarov is in possession
# min 3: M. Mandžukić intercept passage of A. Kolarov
# min 4: M. Mandžukić is in possession
# min 4: K. Manolas intercept passage of M. Mandžukić
# min 5: K. Manolas is in possession
# min 5: K. Manolas fails passing to D. Perotti
# min 6: M. Mandžukić is in possession
# min 6: M. Mandžukić fails passing to G. Higuaín
# min 7: A. Kolarov is in possession
# min 7: A. Kolarov passes to D. Perotti
# min 8: D. Perotti is in possession
# min 8: M. Benatia intercept passage of D. Perotti
# min 9: M. Benatia is in possession
# min 9: M. Benatia fails passing to B. Matuidi
# min 10: D. Perotti is in possession
# min 10: M. Benatia intercept passage of D. Perotti
# min 11: M. Benatia is in possession
# min 11: M. Benatia passes to Alex Sandro
# min 12: Alex Sandro is in possession
# min 12: Alex Sandro passes to M. Pjanić
# min 13: M. Pjanić is in possession
# min 13: SHOOT of M. Pjanić
# min 13: Alisson saves on M. Pjanić
# min 14: Alisson is in possession
# min 14: Alisson fails passing to R. Nainggolan
# min 15: G. Higuaín is in possession
# min 15: K. Manolas intercept passage of G. Higuaín
# min 16: K. Manolas is in possession
# min 16: K. Manolas fails passing to E. Džeko
# min 17: G. Higuaín is in possession
# min 17: SHOOT of G. Higuaín
# min 17: GOAL! G. Higuaín scores for Juventus
# min 18: R. Nainggolan is in possession
# min 18: M. Pjanić intercept passage of R. Nainggolan
# min 19: M. Pjanić is in possession
# min 19: M. Pjanić passes to A. Barzagli
# min 20: A. Barzagli is in possession
# min 20: A. Barzagli passes to Alex Sandro
# min 21: Alex Sandro is in possession
# min 21: Alex Sandro fails passing to A. Barzagli
# min 22: A. Florenzi is in possession
# min 22: SHOOT of A. Florenzi
# min 22: G. Buffon saves on A. Florenzi
# min 23: G. Buffon is in possession
# min 23: G. Buffon passes to G. Chiellini
# min 24: G. Chiellini is in possession
# min 24: G. Chiellini fails passing to M. Benatia
# min 25: D. Perotti is in possession
# min 25: D. Perotti fails passing to A. Florenzi
# min 26: G. Chiellini is in possession
# min 26: G. Chiellini passes to Alex Sandro
# min 27: Alex Sandro is in possession
# min 27: Alex Sandro passes to B. Matuidi
# min 28: B. Matuidi is in possession
# min 28: B. Matuidi passes to M. Pjanić
# min 29: M. Pjanić is in possession
# min 29: R. Nainggolan intercept passage of M. Pjanić
# min 30: R. Nainggolan is in possession
# min 30: R. Nainggolan passes to K. Strootman
# min 31: K. Strootman is in possession
# min 31: C. Marchisio intercept passage of K. Strootman
# min 32: C. Marchisio is in possession
# min 32: SHOOT of C. Marchisio
# min 32: C. Marchisio shoots out
# min 33: Alisson is in possession
# min 33: Alisson fails passing to R. Nainggolan
# min 34: G. Higuaín is in possession
# min 34: G. Higuaín passes to P. Dybala
# min 35: P. Dybala is in possession
# min 35: P. Dybala fails passing to C. Marchisio
# min 36: K. Manolas is in possession
# min 36: K. Manolas fails passing to R. Nainggolan
# min 37: P. Dybala is in possession
# min 37: SHOOT of P. Dybala
# min 37: Alisson saves on P. Dybala
# min 38: Alisson is in possession
# min 38: Alisson fails passing to A. Kolarov
# min 39: G. Higuaín is in possession
# min 39: K. Manolas intercept passage of G. Higuaín
# min 40: K. Manolas is in possession
# min 40: K. Manolas passes to F. Fazio
# min 41: F. Fazio is in possession
# min 41: F. Fazio passes to K. Manolas
# min 42: K. Manolas is in possession
# min 42: P. Dybala intercept passage of K. Manolas
# min 43: P. Dybala is in possession
# min 43: SHOOT of P. Dybala
# min 43: Alisson saves on P. Dybala
# min 44: Alisson is in possession
# min 44: Alisson fails passing to K. Strootman
# min 45: P. Dybala is in possession
# min 45: H. Moreno intercept passage of P. Dybala
# min 46: H. Moreno is in possession
# min 46: SHOOT of H. Moreno
# min 46: H. Moreno shoots out
# min 47: G. Buffon is in possession
# min 47: A. Florenzi intercept passage of G. Buffon
# min 48: A. Florenzi is in possession
# min 48: M. Benatia intercept passage of A. Florenzi
# min 49: M. Benatia is in possession
# min 49: M. Benatia passes to B. Matuidi
# min 50: B. Matuidi is in possession
# min 50: SHOOT of B. Matuidi
# min 50: Alisson saves on B. Matuidi
# min 51: Alisson is in possession
# min 51: Alisson fails passing to E. Džeko
# min 52: M. Mandžukić is in possession
# min 52: SHOOT of M. Mandžukić
# min 52: Alisson saves on M. Mandžukić
# min 53: Alisson is in possession
# min 53: M. Mandžukić intercept passage of Alisson
# min 54: M. Mandžukić is in possession
# min 54: SHOOT of M. Mandžukić
# min 54: Alisson saves on M. Mandžukić
# min 55: Alisson is in possession
# min 55: Alisson fails passing to E. Džeko
# min 56: P. Dybala is in possession
# min 56: H. Moreno intercept passage of P. Dybala
# min 57: H. Moreno is in possession
# min 57: H. Moreno passes to F. Fazio
# min 58: F. Fazio is in possession
# min 58: F. Fazio fails passing to K. Strootman
# min 59: P. Dybala is in possession
# min 59: P. Dybala passes to C. Marchisio
# min 60: C. Marchisio is in possession
# min 60: C. Marchisio passes to M. Pjanić
# min 61: M. Pjanić is in possession
# min 61: R. Nainggolan intercept passage of M. Pjanić
# min 62: R. Nainggolan is in possession
# min 62: SHOOT of R. Nainggolan
# min 62: G. Buffon saves on R. Nainggolan
# min 63: G. Buffon is in possession
# min 63: D. Perotti intercept passage of G. Buffon
# min 64: D. Perotti is in possession
# min 64: D. Perotti passes to R. Nainggolan
# min 65: R. Nainggolan is in possession
# min 65: B. Matuidi intercept passage of R. Nainggolan
# min 66: B. Matuidi is in possession
# min 66: SHOOT of B. Matuidi
# min 66: GOAL! B. Matuidi scores for Juventus
# min 67: R. Nainggolan is in possession
# min 67: SHOOT of R. Nainggolan
# min 67: R. Nainggolan shoots out
# min 68: G. Buffon is in possession
# min 68: G. Buffon fails passing to M. Mandžukić
# min 69: E. Džeko is in possession
# min 69: SHOOT of E. Džeko
# min 69: G. Buffon saves on E. Džeko
# min 70: G. Buffon is in possession
# min 70: G. Buffon fails passing to M. Mandžukić
# min 71: A. Florenzi is in possession
# min 71: A. Florenzi fails passing to D. De Rossi
# min 72: A. Barzagli is in possession
# min 72: A. Florenzi intercept passage of A. Barzagli
# min 73: A. Florenzi is in possession
# min 73: SHOOT of A. Florenzi
# min 73: G. Buffon saves on A. Florenzi
# min 74: G. Buffon is in possession
# min 74: G. Buffon fails passing to M. Benatia
# min 75: D. Perotti is in possession
# min 75: G. Chiellini intercept passage of D. Perotti
# min 76: G. Chiellini is in possession
# min 76: G. Chiellini fails passing to M. Pjanić
# min 77: A. Florenzi is in possession
# min 77: SHOOT of A. Florenzi
# min 77: G. Buffon saves on A. Florenzi
# min 78: G. Buffon is in possession
# min 78: G. Buffon passes to A. Barzagli
# min 79: A. Barzagli is in possession
# min 79: A. Barzagli fails passing to M. Mandžukić
# min 80: D. Perotti is in possession
# min 80: Alex Sandro intercept passage of D. Perotti
# min 81: Alex Sandro is in possession
# min 81: Alex Sandro passes to A. Barzagli
# min 82: A. Barzagli is in possession
# min 82: A. Barzagli passes to G. Chiellini
# min 83: G. Chiellini is in possession
# min 83: G. Chiellini passes to Alex Sandro
# min 84: Alex Sandro is in possession
# min 84: Alex Sandro fails passing to M. Benatia
# min 85: D. Perotti is in possession
# min 85: SHOOT of D. Perotti
# min 85: G. Buffon saves on D. Perotti
# min 86: G. Buffon is in possession
# min 86: G. Buffon fails passing to A. Barzagli
# min 87: A. Florenzi is in possession
# min 87: A. Barzagli intercept passage of A. Florenzi
# min 88: A. Barzagli is in possession
# min 88: A. Florenzi intercept passage of A. Barzagli
# min 89: A. Florenzi is in possession
# min 89: A. Barzagli intercept passage of A. Florenzi
# min 90: A. Barzagli is in possession
# min 90: A. Florenzi intercept passage of A. Barzagli

# %%
print (match.score)
print (["{} ({}')".format(p.name, m) for m, p in match.scorers])
# Out:
# {'Juventus': 2, 'Roma': 0}
# ["G. Higuaín (17')", "B. Matuidi (66')"]

# %% [markdown]
# ## Stats

# %%
H = Team('Juventus', data)
A = Team('FC Barcelona', data)
H.selection(module={Player.DEF: 4, Player.MID: 3, Player.ATT: 3})
A.selection(module={Player.DEF: 4, Player.MID: 3, Player.ATT: 3})

winners = {H.name: 0, A.name: 0, 'X': 0}
scorers = defaultdict(lambda: 0)
for m in range(100):
    match = Match(H, A, duration=90)
    match.kickoff(verbose=False, sleep=0)
    if match.score[H.name] > match.score[A.name]:
        winners[H.name] += 1
    elif match.score[A.name] > match.score[H.name]:
        winners[A.name] += 1
    else:
        winners['X'] += 1
    for m, p in match.scorers:
        scorers[p.name] += 1

# %%
print (winners)
# Out:
# {'Juventus': 33, 'FC Barcelona': 36, 'X': 31}

# %%
for k, v in sorted(scorers.items(), key=lambda x: -x[1]):
    print (k, v)
# Out:
# O. Dembélé 40
# G. Higuaín 36
# L. Suárez 36
# M. Mandžukić 32
# L. Messi 31
# P. Dybala 25
# I. Rakitić 14
# B. Matuidi 9
# M. Pjanić 8
# Sergio Busquets 6
# Alex Sandro 6
# Iniesta 5
# C. Marchisio 3
# Piqué 2
# G. Chiellini 2
# A. Barzagli 2
# S. Umtiti 2
# Jordi Alba 1

# %% [markdown]
# # Visualization

# %%
football = '../data/fifa/fifa_2018.csv'
data = FIFA.load(football)
H = Team('Juventus', data)
A = Team('Napoli', data)
H.selection(module={Player.DEF: 4, Player.MID: 4, Player.ATT: 2})
A.selection(module={Player.DEF: 4, Player.MID: 3, Player.ATT: 3})

# %%
match = Match(H, A, duration=10)

# %%
match.kickoff(show=True, sleep=1, verbose=True)
# Out:
# min 10: Alex Sandro is in possession
# min 10: Alex Sandro passes to M. Pjanić

# %%
print (match.score)
# Out:
# {'Juventus': 0, 'Napoli': 0}

# %%
print (match.scorers)
# Out:
# []
