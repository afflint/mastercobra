# %%
a = 5 + 4

# %% [markdown]
# # Introduzione a Python
# ## Sottotitolo
# - elenco 1
# - elenco 2
#     - elenco 3
#
# **bold**, *corsivo* e testo normale
#
# $$ a = \sum\limits_{i=0}^{N} \frac{1}{1 - i} $$

# %%
a = 8

# %%
print(a)
# Out:
# 8
